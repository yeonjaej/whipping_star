# %%
# Imports
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import scipy.stats
from matplotlib import gridspec
import matplotlib.lines as mlines



plt.rcParams["font.family"] = "serif"



def mumuFrom14(x):
    return np.sin(2*np.arcsin(np.sqrt(x)))**2


def getContour2(x,y,z):
    N=1000

    xi = np.linspace(x.min(), x.max(), N)
    yi = np.linspace(y.min(), y.max(), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

    return [xi,yi,zi]

def getContour(x,y,z,val):
    N=1000

    levels = [val]

    xi = np.linspace(x.min(), x.max(), N)
    yi = np.linspace(y.min(), y.max(), N)
    zi = scipy.interpolate.griddata((x, y), z, (xi[None,:], yi[:,None]), method='cubic')

    cs = plt.contour(xi,yi,zi,levels, colors='black', linewidth=.5)
    
    p = cs.collections[0].get_paths()[0]
    v = p.vertices
    return v


execfile("colors.py")

label_font_size= 28

tick_font_size= 15
text_font_size= 22

c1 = cr1
c0 = gCols[1]
c2 = cb1
c3 = bCols[2]
c3b = bCols[0]

cg = cCols[2]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-481cb7c94e58> in <module>()
#      42
#      43
# ---> 44 execfile("colors.py")
#      45
#      46 label_font_size= 28
#
# IOError: [Errno 2] No such file or directory: 'colors.py'

# %%
# First up, im going to check for differences in using sig or bkg as core of chi^2
core_bkg=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/data_full.dat.b")
core_sig=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/data_full.dat.a")

# %%
#sys+stat
data_full=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/datsui_em.xml.dat")
data_nosbnd=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/datui_em.xml.dat")
data_noub=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/datsi_em.xml.dat")
data_noicarus=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/datsu_em.xml.dat")

data_justub=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/datu_em.xml.dat")
data_justicarus=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/dati_em.xml.dat")
data_justsbnd=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/nue_numu_fit/dats_em.xml.dat")

#stat only
#data_stat_full=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_full_sbn.dat")
#data_stat_nosbnd=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_no_sbnd.dat")
#data_stat_noub=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_no_ub.dat")
#data_stat_noicarus=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_no_icarus.dat")

#data_stat_justub=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_just_ub.dat")
#data_stat_justicarus=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_just_icarus.dat")
#data_stat_justsbnd=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/build/src/data_stat_only_just_sbnd.dat")

# %%
lsnd1=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/LSND_1.csv", delimiter=',')
lsnd2=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/LSND_2.csv", delimiter=',')
lsnd3=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/LSND_3.csv", delimiter=',')

conrad1=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/glob_0_conrad.csv", delimiter=',')
conrad2=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/glob_1_conrad.csv", delimiter=',')
conrad3=np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/glob_2_conrad.csv", delimiter=',')

gui1_mue=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_0_mue.csv", delimiter=',')
gui2_mue=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_1_mue.csv", delimiter=',')
gui3_mue=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_2_mue.csv", delimiter=',')

gui1_ee=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_0_ee.csv", delimiter=',')
gui2_ee=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_1_ee.csv", delimiter=',')
gui3_ee=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_2_ee.csv", delimiter=',')

gui1_mumu=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_0_mumu.csv", delimiter=',')
gui2_mumu=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_2_mumu.csv", delimiter=',')
gui3_mumu=np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/glob_fit/guinti_glob_3_mumu.csv", delimiter=',')

gallium = np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/gallium_anomaly.csv",delimiter=',')
SBN_proposal_mumu= np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/SBN_proposal/SBN_mumu90.csv",delimiter=',')
SBN_proposal_mumu = SBN_proposal_mumu[SBN_proposal_mumu[:,1].argsort()]
mySBN_ee= np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/SBN_proposal/my_SBN_ee90.csv",delimiter=',')
bugey_ee= np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/bugey_ee.csv",delimiter=',')
bugey_ee = bugey_ee[bugey_ee[:,1].argsort()]

miniboone_mumu_90= np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/miniboone_mumu_90.csv",delimiter=',')
miniboone_mumu_90 = miniboone_mumu_90[miniboone_mumu_90[:,1].argsort()]

minos_plus_mumu = np.genfromtxt("/home/mark/work/pheno/sterile_plots/limits_bounds_data/minos_plus_sin2theta.csv",delimiter=',')
minos_plus_mumu = minos_plus_mumu[minos_plus_mumu[:,1].argsort()]



glob =  np.genfromtxt("/home/mark/work/pheno/SBN_osc_analysis/plots/limits/3p1_davio_99_full.dat")[::50]
#select all such ythat 
glob=glob[glob[:,0] > 0.7  ]

globX = 4*glob[:,2]**2*(glob[:,4]**2)
globY = glob[:,0]

glob.size
# Out:
# 99240

# %%
# THIS IS SYS+STAT for nue+numu 

# Create a new subplot from a grid of 1x1
f=plt.figure(figsize=(10,10), dpi=150)

d1 = [12,3] # 5 points on, 2 off, 3 on, 1 off
d2 = [3,3] # 5 points on, 2 off, 3 on, 1 off
d3 = [12,3, 3,3] # 5 points on, 2 off, 3 on, 1 off

ax=plt.subplot(111)
ax.set_xscale("log", nonposx='clip')
ax.set_yscale("log", nonposy='clip')


con1 = getContour((data_full[:,3]),data_full[:,1],data_full[:,5],1.28)


plt.plot(10**con1[:,0], 10**con1[:,1],  color=c1 ,linewidth=3, linestyle="-")

#plt.plot(10**con5[:,0], 10**con5[:,1],  color=cCols[0], linewidth=3, linestyle="-")
#plt.plot(10**con6[:,0], 10**con6[:,1],  color=cCols[1], linewidth=3, linestyle="-")
#plt.plot(10**con7[:,0], 10**con7[:,1],  color=cCols[2], linewidth=3, linestyle="-")


plt.fill(lsnd1[:,0],lsnd1[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5, linestyle="-",alpha=0.7)
plt.fill(lsnd2[:,0],lsnd2[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5,  linestyle="-",alpha=0.7)
plt.fill(lsnd3[:,0],lsnd3[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5,  linestyle="-",alpha=0.7)

plt.fill(gui1_mue[:,0],gui1_mue[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5, linestyle="-",alpha=0.7)
plt.fill(gui2_mue[:,0],gui2_mue[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)
plt.fill(gui3_mue[:,0],gui3_mue[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)

# This is our SBNfit one
#plt.plot(globX, globY, color=cg,linestyle="None", marker=".", markersize=10)


ax.set_xlabel(r'$\sin^2 2 \theta_{\mu e}$',fontsize=label_font_size)
ax.set_ylabel(r'$\Delta m_{41}^2$  [eV$^2$]',fontsize=label_font_size)


# Set axis limits and 
plt.xlim(1e-5,1)
plt.ylim(0.01,100)

ax.tick_params('both',labelsize=tick_font_size)
ax.tick_params('both',length=7, width=1, which='minor' )
ax.tick_params('both',length=13, width=1.7, which='major' )

plt.annotate('Global allowed 3$\sigma$\nGariazzo et al.\n(1703.0086)',
             xy=(2.5e-3, 1.3), xycoords='data',color=cg,
             xytext=(+50, +50), textcoords='offset points', fontsize=text_font_size,
             arrowprops=dict(arrowstyle="fancy", connectionstyle="arc3,rad=.2",color=cg))

plt.annotate('LSND allowed\n at 99% C.L',
             xy=(3e-3, 15), xycoords='data',color=c3,
             xytext=(+50, +50), textcoords='offset points', fontsize=text_font_size,
             arrowprops=dict(arrowstyle="fancy", connectionstyle="arc3,rad=.2",color=c3,))


plt.annotate('3+1 $\\nu_e$ Appearance Only\nNeutrino mode only\nSBND,ICARUS 6.6e20 POT\nMicroBooNE 13.2e20 POT',
             xy=(0.05, 0.05), xycoords='axes fraction',fontsize=text_font_size-4)

proxy = [mlines.Line2D([], [], color=pc,linewidth=3) 
    for pc in [c1]]

leg=plt.legend(proxy, ["SBN 90% C.L",],fontsize=20,loc=(0.075,0.25))
leg.get_frame().set_linewidth(0.0)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

# Show result on screen
plt.show()
f.savefig("full_SBN_mue.pdf", bbox_inches='tight')

# %%
# THIS IS SYS+STAT for mumu

# Create a new subplot from a grid of 1x1
f=plt.figure(figsize=(10,10), dpi=150)

d1 = [12,3] # 5 points on, 2 off, 3 on, 1 off
d2 = [3,3] # 5 points on, 2 off, 3 on, 1 off
d3 = [12,3, 3,3] # 5 points on, 2 off, 3 on, 1 off

ax=plt.subplot(111)
ax.set_xscale("log", nonposx='clip')
ax.set_yscale("log", nonposy='clip')


plt.plot(bugey_ee[:,0], bugey_ee[:,1],  color=c3 ,linewidth=3, linestyle="-")
plt.plot(mySBN_ee[:,0], mySBN_ee[:,1],  color=c1 ,linewidth=3, linestyle="-")


#plt.plot(10**con5[:,0], 10**con5[:,1],  color=cCols[0], linewidth=3, linestyle="-")
#plt.plot(10**con6[:,0], 10**con6[:,1],  color=cCols[1], linewidth=3, linestyle="-")
#plt.plot(10**con7[:,0], 10**con7[:,1],  color=cCols[2], linewidth=3, linestyle="-")

#plt.fill(lsnd1[:,0],lsnd1[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5, linestyle="-",alpha=0.7)
#plt.fill(lsnd2[:,0],lsnd2[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5,  linestyle="-",alpha=0.7)
#plt.fill(lsnd3[:,0],lsnd3[:,1], edgecolor=c3, facecolor=c3b, linewidth=2.5,  linestyle="-",alpha=0.7)
plt.fill(gallium[:,0],gallium[:,1], edgecolor=gCols[2], facecolor=c0, linewidth=2.5, linestyle="-",alpha=0.7)


plt.fill(gui1_ee[:,0],gui1_ee[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5, linestyle="-",alpha=0.7)
plt.fill(gui2_ee[:,0],gui2_ee[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)
plt.fill(gui3_ee[:,0],gui3_ee[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)

# This is our SBNfit one
#plt.plot(globX, globY, color=cg,linestyle="None", marker=".", markersize=10)


ax.set_xlabel(r'$\sin^2 2 \theta_{e e}$',fontsize=label_font_size)
ax.set_ylabel(r'$\Delta m_{41}^2$  [eV$^2$]',fontsize=label_font_size)


# Set axis limits and 
plt.xlim(1e-3,1)
plt.ylim(0.01,100)

ax.tick_params('both',labelsize=tick_font_size)
ax.tick_params('both',length=7, width=1, which='minor' )
ax.tick_params('both',length=13, width=1.7, which='major' )

plt.annotate('Global allowed 3$\sigma$\nGariazzo et al.\n(1703.0086)',
             xy=(3e-2, 1.6), xycoords='data',color=cg,
             xytext=(-200, +50), textcoords='offset points', fontsize=text_font_size,
             arrowprops=dict(arrowstyle="fancy", connectionstyle="arc3,rad=.2",color=cg))

plt.annotate('Gallium Anomaly\n at 90% C.L',
             xy=(5e-2, 60), xycoords='data',color=c0,
             xytext=(-250, -25), textcoords='offset points', fontsize=text_font_size,
             arrowprops=dict(arrowstyle="fancy", connectionstyle="arc3,rad=.0",color=c0))


plt.annotate('3+1 $\\nu_e$ Disappearance Only\nNeutrino mode only\nSBND,ICARUS 6.6e20 POT\nMicroBooNE 13.2e20 POT',
             xy=(0.05, 0.05), xycoords='axes fraction',fontsize=text_font_size-4)

proxy = [mlines.Line2D([], [], color=pc,linewidth=3) 
    for pc in [c1,c3]]

leg=plt.legend(proxy, ["SBN 90% C.L","BUGEY 90% C.L"],fontsize=20,loc=(0.07,0.25))
leg.get_frame().set_linewidth(0.0)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

# Show result on screen
plt.show()
f.savefig("full_SBN_ee.pdf", bbox_inches='tight')

# %%
# THIS IS SYS+STAT for nue+numu 

# Create a new subplot from a grid of 1x1
f=plt.figure(figsize=(10,10), dpi=150)

d1 = [12,3] # 5 points on, 2 off, 3 on, 1 off
d2 = [3,3] # 5 points on, 2 off, 3 on, 1 off
d3 = [12,3, 3,3] # 5 points on, 2 off, 3 on, 1 off

ax=plt.subplot(111)
ax.set_xscale("log", nonposx='clip')
ax.set_yscale("log", nonposy='clip')


#plt.plot(miniboone_mumu_90[:,0], miniboone_mumu_90[:,1],  color=oCols[1] ,linewidth=3, linestyle="-")
plt.plot( np.sin(2*np.arcsin(np.sqrt(minos_plus_mumu[:,0])))**2, minos_plus_mumu[:,1], color=oCols[1]  ,linewidth=3, linestyle="-")
plt.plot(SBN_proposal_mumu[:,0], SBN_proposal_mumu[:,1],  color=c1 ,linewidth=3, linestyle="-")


plt.fill(gui1_mumu[:,0],gui1_mumu[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5, linestyle="-",alpha=0.7)
plt.fill(gui2_mumu[:,0],gui2_mumu[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)
plt.fill(gui3_mumu[:,0],gui3_mumu[:,1], edgecolor=cg, facecolor=cCols[1], linewidth=2.5,  linestyle="-",alpha=0.7)

# This is our SBNfit one
#plt.plot(globX, globY, color=cg,linestyle="None", marker=".", markersize=10)


ax.set_xlabel(r'$\sin^2 2 \theta_{\mu \mu}$',fontsize=label_font_size)
ax.set_ylabel(r'$\Delta m_{41}^2$  [eV$^2$]',fontsize=label_font_size)


# Set axis limits and 
plt.xlim(1e-4,1)
plt.ylim(0.01,100)

ax.tick_params('both',labelsize=tick_font_size)
ax.tick_params('both',length=7, width=1, which='minor' )
ax.tick_params('both',length=13, width=1.7, which='major' )

plt.annotate('Global allowed 3$\sigma$\nGariazzo et al.\n(1703.0086)',
             xy=(0.02, 2.5), xycoords='data',color=cg,
             xytext=(-280, +50), textcoords='offset points', fontsize=text_font_size-2,
             arrowprops=dict(arrowstyle="fancy",connectionstyle="arc3,rad=.2", color=cg))


plt.annotate('3+1 $\\nu_\mu$ Disappearance Only\nNeutrino mode only\nSBND,ICARUS 6.6e20 POT\nMicroBooNE 13.2e20 POT',
             xy=(0.05, 0.05), xycoords='axes fraction',fontsize=text_font_size-4)

proxy = [mlines.Line2D([], [], color=pc,linewidth=3) 
    for pc in [c1,oCols[1]]]

leg=plt.legend(proxy, ["SBN 90% C.L","MINOS+ 90% C.L"],fontsize=20,loc=(0.055,0.225))
leg.get_frame().set_linewidth(0.0)

# Set y ticks
#plt.yticks(np.linspace(-1,1,5,endpoint=True))

# Save figure using 72 dots per inch
# savefig("../figures/exercice_2.png",dpi=72)

# Show result on screen
plt.show()
f.savefig("full_SBN_mumu.pdf", bbox_inches='tight')
